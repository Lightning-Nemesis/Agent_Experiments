# %% [markdown]
# # Data Ingestion

# %%
### Document data structure
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Krish Naik",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# C:\Users\amrit\AppData\Local\Temp\ipykernel_38264\2416650908.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m147', 'creator': 'FlowCV - https://flowcv.com', 'creationdate': '2026-05-27T18:42:07+00:00', 'source': '..\\data\\pdf\\Amrit-Mahajan-FlowCV-Cover-Letter.pdf', 'file_path': '..\\data\\pdf\\Amrit-Mahajan-FlowCV-Cover-Letter.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': 'FlowCV – Online Resume Builder – https://flowcv.com', 'moddate': '2026-05-27T18:42:07+00:00', 'trapped': '', 'modDate': "D:20260527184207+00'00'", 'creationDate': "D:20260527184207+00'00'", 'page': 0}, page_content="Amrit Mahajan\namrit.mahajan007\u200b@gmail.com\n \n(480)527-3622\n \nTempe, AZ\n \namrit-mahajan\n \nDear Hiring Committee,\nI am expressing my strong interest in the Forward Deployed Engineer role at Cornerstone OnDemand.\nI've completed my Master's in Computer Science at Arizona State University and bring a strong\nfoundation in data science & machine learning, along with a deep passion for technology.\nIn my recent internship at Wells Fargo as a Quantitative Analyst on the GenAI team, I contributed to\nsolutions that streamlined customer data access for bankers using large language models and retrieval\naugmented generation (RAG). I helped design and evaluate a chatbot assistant that enabled natural\nlanguage querying across multiple internal systems, significantly improving response speed and\nreducing call preparation time. This hands-on experience with applied NLP and production-grade AI\nsystems further strengthened my data science and engineering capabilities.\nBefore this, at Bajaj Finance in their App division, I applied my data science and analytics skills to large-\nscale datasets with over 50 million records, including customer interaction data and clickstream data,\nusing Databricks. I handled the entire data lifecycle, from preprocessing and analysis to building and\nmaintaining machine learning models. My achievements include developing a Customer Churn\nPrediction model that improved retention on the app by 3.8%, a notification recommendation engine\nthat boosted user engagement, and forecasting metrics that helped the business anticipate trends,\nallocate resources, and make informed decisions. This experience has prepared me well for the duties\noutlined in the position.\nBeyond my technical expertise, I am a Certified Trainer and a Dale Carnegie Training Excellence\ngraduate, which has strengthened my communication and interpersonal skills. I’ve delivered technical\nsessions at work to 60+ employees, refining my ability to explain complex concepts and collaborate\nacross teams.\nI’m excited about the opportunity to solve problems and build impactful solutions. With my technical\nexpertise, adaptability, and proactive mindset, I’m confident I can contribute meaningfully to this role.\nSincerely,\nAmrit Mahajan"),
#  Document(metadata={'producer': 'Skia/PDF m150 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Resume_Amrit_Mahajan_GenAI.pdf', 'file_path': '..\\data\\pdf\\Resume_Amrit_Mahajan_GenAI.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Amrit_Mahajan_Resume_GenAI', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Amrit Mahajan \n \n480-527-3622 | amrit.mahajan007@gmail.com | linkedin.com/in/amrit-mahajan | lightning-nemesis.github.io \n \nEDUCATION \nArizona State University\u200b\nTempe, Arizona \nMaster of Science in Computer Science | GPA: 4.0/4.0\u200b\nAug. 2024 - May 2026 \n●\u200b\nRelevant Coursework - Natural Language Processing, Semantic Web Mining, Statistical Machine Learning, Data \nMining, Cloud Computing, Data-intensive systems for ML, Data Visualization \n \nVellore Institute of Technology, Vellore\u200b\nVellore, India \nBachelor’s in Computer Science | GPA: 9.29/10 | Merit Scholarship Recipient (Top 10 rank)\u200b\nJul. 2018 - May 2022 \n \nWORK EXPERIENCE \nWells Fargo\u200b\nCharlotte, NC \nGen AI Intern, Quantitative Analytics Program\u200b\nJune 2025 - Aug. 2025 \n●\u200b\nBuilt a POC Generative AI Question Answering system using customer data, providing bankers with accurate \ncontext-aware insights and reducing client preparation time by ~30% in pilot testing. \n●\u200b\nDesigned an LLM evaluation framework using DeepEval and DSPy, implementing HITL, LLM-as-a-judge, and \nadversarial testing to benchmark model reliability, alignment, and safety across projects. \n●\u200b\nTested a hybrid RAG pipeline (BM25 + FAISS) that reduced retrieval latency by ~85% by replacing long-context \nlarge-model prompting with targeted chunk retrieval and smaller models. \n \nBajaj Finance Limited\u200b\n Pune, India \nData Scientist\u200b\nJul. 2022 - Jul. 2024 \n●\u200b\nLed development and deployment of ML-based Customer Churn Prediction model on the Bajaj Finserv App \n(40M+ users), driving a 3.8% retention lift through targeted strategies. \n●\u200b\nBuilt a Notification Recommendation Engine using sequence modeling on clickstream data that boosted \nnotification click-through rates by 25%, directly improving business leads, journey completions, and conversions. \n●\u200b\nPioneered MLOps adoption by implementing MLflow in Databricks, cutting manual deployment effort by 50%, \nstandardizing A/B testing, and enabling adoption by 3+ teams. \n \nBajaj Finance Limited\u200b\n Pune, India \nData Science Intern\u200b\nJan. 2022 - Jul. 2022 \n●\u200b\nAutomated forecasting pipelines using Pandas and PySpark, cutting monthly reporting time for app metrics \n(MAU, DAU, traffic, and net users) from 5–6 days in Excel to 1 day. \n●\u200b\nAnalyzed app notifications and uninstallation patterns using tree-based models, guiding informed governance \nchanges that reduced churn and notification costs. \n \nSKILLS \nProgramming: Python, SQL, Pyspark, C++, NumPy, Pandas \nAI/ML: Statistics, Predictive Modeling, Time Series, Deep Learning, NLP, LLMs, MLOps, Prompt Engineering, \nFine-tuning & Alignment, Retrieval Augmented Generation (RAG), Agentic Workflows, LLM Evaluation & Safety \nFrameworks/Tools: TensorFlow, Hugging Face, LangChain, Vector Databases, DeepEval, DSPy, scikit-learn, streamlit \nCertifications :  \n●\u200b\nTechnical: Generative AI with LLMs, TensorFlow Developer Professional Certificate (DeepLearning.AI, 2023-2024) \n●\u200b\nProfessional: Dale Carnegie Program on Training Excellence (Dale Carnegie & Associates, Inc., Mar. 2024) \nPROJECTS \nIdentifying LLM Performance Gaps Across Languages | Research Project at ASU \n●\u200b\nEvaluated multilingual performance gaps in LLMs using OLMo models across 100+ languages and 5 reasoning \ndomains (Math, Reasoning, NLI, Common sense, healthcare) using high-quality translation pipelines. \n●\u200b\nQuantified correlation between structural factors (langua ...
#  Document(metadata={'producer': 'Oracle Analytics Publisher', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\SSR_TSRPT.pdf', 'file_path': '..\\data\\pdf\\SSR_TSRPT.pdf', 'total_pages': 1, 'format': 'PDF 1.6', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Arizona State University\nPage 1 of 1\nUnofficial Transcript\nName:           Amrit Vinod Mahajan\nStudent ID:   1234319010\n_____________________________________________________________\nPrint Date: \n12/16/2025\nExternal Degrees\nVIT University\nBachelor of Technology\n07/01/2022\nBeginning of Graduate Record \n      \n   \n2024 Fall \nCourse\nDescription\nAttempted\nEarned\nGrade\nPoints\nCSE  572 \nData Mining\n3.000\n3.000\nA+\n12.999\nCSE  575 \nStatistical Machine \nLearning\n3.000\n3.000\nA\n12.000\nCSE  579 \nKnowledge \nRepresentation\n3.000\n3.000\nA+\n12.999\nAttempted\nEarned\nPoints\nTerm GPA:\n4.00 \nTerm Totals\n9.000\n9.000\n37.998\nCum GPA:\n4.00 \nCum Totals\n9.000\n9.000\n37.998\n      \n   \n2025 Spring \nCourse\nDescription\nAttempted\nEarned\nGrade\nPoints\nCSE  571 \nArtificial Intelligence\n3.000\n3.000\nA+\n12.999\nCSE  578 \nData Visualization\n3.000\n3.000\nA+\n12.999\nCSE  598 \nSpecial Topics\n3.000\n3.000\nA+\n12.999\nCourse Topic:\nData-Intens Sys for Mach Learn \nAttempted\nEarned\nPoints\nTerm GPA:\n4.00 \nTerm Totals\n9.000\n9.000\n38.997\nCum GPA:\n4.00 \nCum Totals\n18.000\n18.000\n76.995\n      \n   \n2025 Summer \nCourse\nDescription\nAttempted\nEarned\nGrade\nPoints\nCSE  584 \nInternship\n1.000\n1.000\nY\n0.000\nCourse Topic:\nCurricular Practical Training \nAttempted\nEarned\nPoints\nTerm GPA:\n0.00 \nTerm Totals\n1.000\n1.000\n0.000\nCum GPA:\n4.00 \nCum Totals\n19.000\n19.000\n76.995\n      \n   \n2025 Fall \nCourse\nDescription\nAttempted\nEarned\nGrade\nPoints\nCSE  511 \nData Processing at \nScale\n3.000\n3.000\nA+\n12.999\nCSE  546 \nCloud Computing\n3.000\n3.000\nA+\n12.999\nCSE  576 \nTopics/Natural \nLanguage Proc\n3.000\n3.000\nA\n12.000\nAttempted\nEarned\nPoints\nTerm GPA:\n4.00 \nTerm Totals\n9.000\n9.000\n37.998\nCum GPA:\n4.00 \nCum Totals\n28.000\n28.000\n114.993\n      \n   \n2026 Spring \nCourse\nDescription\nAttempted\nEarned\nGrade\nPoints\nCSE  573 \nSemantic Web Mining\n3.000\n0.000\nNR\n0.000\nAttempted\nEarned\nPoints\nTerm GPA:\n0.00 \nTerm Totals\n0.000\n0.000\n0.000\nCum GPA:\n4.00 \nCum Totals\n28.000\n28.000\n114.993\nEND OF TRANSCRIPT')]
